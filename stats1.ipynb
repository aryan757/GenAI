# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2021-07-18' , periods= 10) , columns=['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527

# %%
df["new"] = df['c'] +df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913

# %%
df["new_col_square_d"] = df["d"].apply(lambda x : x**2)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_square_d
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725          5.490876
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012          0.957425
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950          0.243454
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787          0.060376
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477          0.165135
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910          1.776298
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169          2.421716
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073          1.220096
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928          2.601737
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913          1.291693

# %%
df["new_col_square_log"] = df["d"].apply(lambda x : np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_log
# 2021-07-18          5.490876                 NaN
# 2021-07-19          0.957425                 NaN
# 2021-07-20          0.243454                 NaN
# 2021-07-21          0.060376           -1.403582
# ...

# %%
def test(x):
    if(x<0):
        return x
    else:
        return np.log(x)

# %%
df["new_col_square_log"] = df["d"].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_log
# 2021-07-18          5.490876           -2.343262
# 2021-07-19          0.957425           -0.978481
# 2021-07-20          0.243454           -0.493411
# 2021-07-21          0.060376           -1.403582
# ...

# %%
## make a new column , to check if data set in in 'a' , if it is less that 0 then put 1 , else 0 !!

# %%
def test1(x):
    if x<0 :
        return 1
    else :
        return 0

# %%
df["new_a"] = df["a"].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_log  new_a
# 2021-07-18          5.490876           -2.343262      0
# 2021-07-19          0.957425           -0.978481      1
# 2021-07-20          0.243454           -0.493411      0
# 2021-07-21          0.060376           -1.403582      1
# ...

# %%
##new operation

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_log  new_a
# 2021-07-18          5.490876           -2.343262      0
# 2021-07-19          0.957425           -0.978481      1
# 2021-07-20          0.243454           -0.493411      0
# 2021-07-21          0.060376           -1.403582      1
# ...

# %%
df.sort_values(by = "b")
# Out:
#                    a         b         c         d       new  \
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
#
#             new_col_square_d  new_col_square_log  new_a
# 2021-07-23          1.776298            0.287266      1
# 2021-07-25          1.220096           -1.104579      0
# 2021-07-27          1.291693           -1.136527      0
# 2021-07-21          0.060376           -1.403582      1
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
##here i have taken index as a DATE here , now if i have to treat this index as as column  what we ahave to do ?

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21',
#                '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25',
#                '2021-07-26', '2021-07-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
df["new_date"] = df.index

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_log  new_a   new_date
# 2021-07-18          5.490876           -2.343262      0 2021-07-18
# 2021-07-19          0.957425           -0.978481      1 2021-07-19
# 2021-07-20          0.243454           -0.493411      0 2021-07-20
# ...

# %%
df.dtypes
# Out:
# a                            float64
# b                            float64
# c                            float64
# d                            float64
# new                          float64
# new_col_square_d             float64
# new_col_square_log           float64
# new_a                          int64
# new_date              datetime64[ns]
# dtype: object

# %%
##so here my task is to seperate , date as new column as month,year,date ?

# %%
##as it is given above aboout its dtypes !! i.e datetime values!

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year

# %%
df
# Out:
#                    a         b         c         d       new  \
# 2021-07-18  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-19 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-20  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-21 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-22 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-23 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-24 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-25  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-26  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-27  0.527070 -1.551101  0.329613 -1.136527 -0.806913
#
#             new_col_square_d  new_col_square_log  new_a   new_date  day  \
# 2021-07-18          5.490876           -2.343262      0 2021-07-18   18
# 2021-07-19          0.957425           -0.978481      1 2021-07-19   19
# 2021-07-20          0.243454           -0.493411      0 2021-07-20   20
# ...

# %% [markdown]
# # Matplotlib - Data Visualisations !!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1),index = pd.date_range('2021-07-18',periods = 1000) ,columns=['data'])

# %%
df.plot

# %%
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum()
# Out:
# 2021-07-18      0.588131
# 2021-07-19      1.485845
# 2021-07-20      2.377375
# 2021-07-21      3.193213
# 2021-07-22      3.229102
#                  ...
# 2024-04-08    495.812936
# 2024-04-09    496.568973
# 2024-04-10    496.868159
# 2024-04-11    497.129872
# 2024-04-12    498.098851
# Freq: D, Name: data, Length: 1000, dtype: float64

# %%
type(df.data.cumsum())
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda x : x**3)

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  0.203433
# 2021-07-19  0.897714    1.485845  0.723458
# 2021-07-20  0.891531    2.377375  0.708613
# 2021-07-21  0.815837    3.193213  0.543014
# 2021-07-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  0.976749
# 2024-04-09  0.756037  496.568973  0.432145
# 2024-04-10  0.299186  496.868159  0.026781
# 2024-04-11  0.261712  497.129872  0.017926
# 2024-04-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (20 ,10))
# Out:
# <AxesSubplot:>

# %%
sns.load_dataset('iris') ##here sns is called the seaborn !!
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
##insid ethe seaborn , there is so many data set which is prresent !

# %%
df1 = sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(figsize = (10 , 10 ))
# Out:
# <AxesSubplot:>

# %%
df1.plot(figsize = (10 , 10 ) , title = 'irish data')
# Out:
# <AxesSubplot:title={'center':'irish data'}>

# %%
gf = df1.plot(figsize = (10 , 10 ) , title = 'irish data')

# %%
gf = df1.plot(figsize = (5,5) , title = "irish data")
gf.set_xlabel("this is my x axis")
gf.set_ylabel("this is my y axis")
# Out:
# Text(0, 0.5, 'this is my y axis')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  0.203433
# 2021-07-19  0.897714    1.485845  0.723458
# 2021-07-20  0.891531    2.377375  0.708613
# 2021-07-21  0.815837    3.193213  0.543014
# 2021-07-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  0.976749
# 2024-04-09  0.756037  496.568973  0.432145
# 2024-04-10  0.299186  496.868159  0.026781
# 2024-04-11  0.261712  497.129872  0.017926
# 2024-04-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df2 = sns.load_dataset("titanic")

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
type(df2['pclass'])
# Out:
# pandas.core.series.Series

# %%
df2['pclass'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %% [markdown]
# ###

# %%
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh() ##bar horixontal
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_width'].describe()
# Out:
# count    150.000000
# mean       3.057333
# std        0.435866
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: sepal_width, dtype: float64

# %%
df1['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
##incase of histogram , our x axis is representing a range ! 
## and y axis is representing a frequency !!

# %%
df1.plot (kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram_irish")
# Out:
# <AxesSubplot:title={'center':'histogram_irish'}, ylabel='Frequency'>

# %%
## here bins is representing the width , of the graph !!

# %%
## and stacked is representing the graphical overlap !

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram_irish" , orientation = "horizontal")
# Out:
# <AxesSubplot:title={'center':'histogram_irish'}, xlabel='Frequency'>

# %%
##no need to remembr anything !

# %%
## suppose my task is to plot seperate - seprerate histogram !

# %%
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
##it will represent for all columns !

# %%
df1.hist(figsize=(10,10),color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
##or go to html color , type in google and choose the hexa code for any color !

# %%
df1.hist(figsize=(10,10),color = '#90ee90')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize=(10,10),color = '#90ee90' , alpha = .9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
##alpha is use to increase or decrease the contrasrt of the graph !!

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## now suppose if , i have to understand the relatuonship between 
## columns given , how do we do that ?

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.scatter(x ='sepal_width' , y ='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.plot.scatter(x ='sepal_length' , y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_width' , y = 'petal_width' , c ='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1  ##these type of graph helps us to find out , the dependency on the thrid elemenrt !
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## so , in simple word , we are try to creatre a color 
## varable , on which the the dependent varaiable . x and y is dependent !

# %%
##next thin !

# %%
df1.plot.scatter(x = "sepal_length" , y ="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
##more beautifiaction n

# %%
df1.plot.hexbin(x = "sepal_length" , y ="sepal_width" , label = "sudh" ,  gridsize= 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
## 's ' is size

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  0.203433
# 2021-07-19  0.897714    1.485845  0.723458
# 2021-07-20  0.891531    2.377375  0.708613
# 2021-07-21  0.815837    3.193213  0.543014
# 2021-07-22  0.035890    3.229102  0.000046
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  0.976749
# 2024-04-09  0.756037  496.568973  0.432145
# 2024-04-10  0.299186  496.868159  0.026781
# 2024-04-11  0.261712  497.129872  0.017926
# 2024-04-12  0.968979  498.098851  0.909794
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d
# Out:
# data     0.588131
# data1    0.588131
# data2    0.203433
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
##another plot !

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
d.plot.pie(figsize = (10,10))
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.head(3).T
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris = df1.head(3).T

# %%
iris.iloc[0:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
iris.iloc[0:4].plot.pie( subplots = True ,figsize = (20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris.iloc[0:4]
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
##beautifications !

# %%
iris.iloc[0:4].plot.pie( subplots = True ,figsize = (20,20) , fontsize = 20 , autopct = "%.2f")
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
###till now whatever operations , that we have perform ...it is just
## with the help of pandas plot!!

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## RElation ship between every column to every column !!

##scatterd matrixes!! just used the pandas librabry !

# %%
pd.plotting.scatter_matrix(df1, figsize = (10,10))
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
temp = pd.plotting.scatter_matrix(df1, figsize = (10,10))

# %%
type(temp)
# Out:
# numpy.ndarray

# %%
temp[0][0]
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>

# %%
##suppoose ,if i dont want histogram !! in diagonal

# %%
temp = pd.plotting.scatter_matrix(df1, figsize = (10,10) , diagonal = ' kde')

# %%
df['data'].plot(style = 'r--')
# Out:
# <AxesSubplot:>

# %%
df['data'].plot(style = 'r*' , legend = True , label = 'sudh')
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Installation of plotly !!

# %%
# !pip install plotly
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.offline.init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
py.__version__
# Out:
# '5.6.0'

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.iplot()
# Out:
# <div>                            <div id="b1b31e78-7b4c-4b84-86a2-2f911d253517" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
## dont get afrraid of watching these things ... for the first time 

##it may look horriblr , but by the time and practise 

##you will get accoustemed to it !

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.iplot(kind = 'bar' , x = "fare" , y = "age" , xTitle = "fare" , yTitle = "age")
# Out:
# <div>                            <div id="be0b83b4-119e-4824-96c1-163b57f4027c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(x = "fare" , y = "age")
# Out:
# <div>                            <div id="32a46e4f-68c0-42b0-8c04-daf34a15af7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(x = "fare" , y = "age" , kind = "scatter" , mode = "markers" )
# Out:
# <div>                            <div id="f9d06241-3c19-414a-a3e3-5bc915bd3142" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.iplot(x = "fare" , y = "age" , kind = "scatter" , mode = "markers" , xTitle = "fare" , yTitle = "age")
# Out:
# <div>                            <div id="9f84759a-57af-4128-acf6-44fc424f1ad4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
