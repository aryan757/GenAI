# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips  = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x = 'tip' , y = 'total_bill' , data = tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue ='smoker')

# %%
##hue is , with the help of colors , we are trying to represent that

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue ='day')

# %%
##will you able to tell me , on thrusdy , who is smoker and non smoker !

# %%
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue ='day' , style ='smoker')

# %%
##i would like to represent each and every group on the size of a person !

# %%
sns.relplot(x = 'tip' , y = 'total_bill' , data = tips , hue ='day' , style ='smoker' , size = 'size')

# %%
df = pd.DataFrame(np.random.randn(300,2) , columns= [ 'a' , 'b'])

# %%
df
# Out:
#             a         b
# 0   -0.070089  0.947798
# 1   -0.674479  0.503586
# 2   -0.374166  1.135005
# 3    0.752573 -0.139532
# 4   -0.404335 -1.633522
# ..        ...       ...
# 295  0.520762  1.212310
# 296 -0.160489  1.435045
# 297 -0.461746  0.080528
# 298  0.249079  1.367075
# 299  0.504201 -0.463885
#
# [300 rows x 2 columns]

# %%
sns.relplot(x = 'a' , y = 'b' , kind = 'line' , data = df)

# %%
sns.relplot(x = 'a' , y = 'b' , kind = 'line' , data = df , sort = True)

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x = 'sepal_length' , y = 'sepal_width' , data =iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.catplot(x = 'day' , y ='tip' , data = tips)

# %%
##here we are maintaining graph for categorical data and numerical data !!

# %%
sns.catplot(x = 'smoker' , y ='tip' , data = tips)

# %%
##who has given a more number of tips  ?
##who has givean a maximum tip ?

# %%
sns.catplot(x = 'day' , y = 'tip' , kind = 'box' , data = tips)

# %%
sns.catplot(x = 'day' , y = 'tip' , kind = 'box' , data = tips , hue = 'sex')

# %%
x = np.random.randn(10000)

# %%
x
# Out:
# array([-0.72218656, -0.62612143,  0.95652063, ..., -0.01932908,
#         1.86691174, -0.13737178])

# %%
##suppose , we have to check whwrther this data is normally distrubuted or not !!

# %%
sns.distplot(x)
# Out:
# C:\Users\aryan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x = tips['total_bill'] , y = tips['tip']) ##means two graph , it will try to poppulate !

# %%
sns.jointplot(x = tips['total_bill'] , y =tips['tip'], kind = 'hex')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.lmplot(x = 'total_bill'  , y = 'tip' , data = tips)

# %%
##this is the best fitted line , without calling linerar regression !

# %%
sns.regplot(x = 'total_bill' , y ='tip' , data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
##regression plot

# %%
sns.lmplot(x = 'total_bill' , y = 'tip' , data = tips , col = 'day')
